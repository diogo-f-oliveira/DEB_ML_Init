# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# %% [markdown]
# # Load results

# %%
test_resuls_folder = '../project_code/debtool_port/tests'
df = pd.read_csv(f'{test_resuls_folder}/test_init_DEBInitNet_20250708.csv', index_col=0)
error_columns = df.columns[4:-1]
df[error_columns] = df[error_columns].astype(bool)
df
# Out:
#                              amp_loss  init_loss  final_loss  execution_time  \
# Row
# Abatus_cordatus              0.000000   0.000000    0.000000        3.226970
# Abbottina_rivularis          0.028848   0.365939    0.020746       15.652451
# Ablennes_hians               0.015129   1.716545    0.756190       28.538842
# Abra_segmentum               0.000000   0.000000    0.000000        3.734052
# Abralia_multihamata          0.000000   0.000000    0.000000        4.315595
# ...                               ...        ...         ...             ...
# Zosterisessor_ophiocephalus  0.000000   0.000000    0.000000        0.113567
# Zosterops_lateralis          0.000000   0.000000    0.000000        1.159346
# Zosterops_virens             0.000000   0.000000    0.000000        0.216007
# Zygochlamys_patagonica       0.000000   0.000000    0.000000        0.346693
# Zygodontomys_brevicauda      0.000000   0.000000    0.000000        0.334988
#
#                              predict_failed  estim_error  init_func_error  \
# Row
# Abatus_cordatus                       False        False             True
# Abbottina_rivularis                   False        False            False
# Ablennes_hians                        False        False            False
# Abra_segmentum                        False        False             True
# Abralia_multihamata                   False        False             True
# ...                                     ...          ...              ...
# Zosterisessor_ophiocephalus           False        False            False
# Zosterops_lateralis                   False         True            False
# Zosterops_virens                      False        False            False
# Zygochlamys_patagonica                False        False             True
# Zygodontomys_brevicauda               False        False             True
#
#                              fetch_error  convert_error  debnet_error  \
# Row
# Abatus_cordatus                    False          False         False
# Abbottina_rivularis                False          False         False
# Ablennes_hians                     False          False         False
# Abra_segmentum                     False          False         False
# Abralia_multihamata                False          False         False
# ...                                  ...            ...           ...
# Zosterisessor_ophiocephalus        False          False         False
# Zosterops_lateralis                False          False         False
# Zosterops_virens                   False          False         False
# Zygochlamys_patagonica             False          False         False
# Zygodontomys_brevicauda            False          False         False
#
#                              predict_error  lossfun_error  error  \
# Row
# Abatus_cordatus                      False          False   True
# Abbottina_rivularis                  False          False  False
# Ablennes_hians                       False          False  False
# Abra_segmentum                       False          False   True
# Abralia_multihamata                  False          False   True
# ...                                    ...            ...    ...
# Zosterisessor_ophiocephalus          False           True   True
# Zosterops_lateralis                  False          False   True
# Zosterops_virens                     False           True   True
# Zygochlamys_patagonica               False          False   True
# Zygodontomys_brevicauda              False          False   True
#
#                                                                  error_message
# Row
# Abatus_cordatus              Missing data on age at birth. \n\nDEBInitNet i...
# Abbottina_rivularis                                                        NaN
# Ablennes_hians                                                             NaN
# Abra_segmentum               Missing data on age at birth. \n\nDEBInitNet i...
# Abralia_multihamata          Missing data on weight at birth, puberty, or u...
# ...                                                                        ...
# Zosterisessor_ophiocephalus  Dimensions of arrays being concatenated are no...
# Zosterops_lateralis          The logical indices contain a true value outsi...
# Zosterops_virens             Dimensions of arrays being concatenated are no...
# Zygochlamys_patagonica       Missing data on age at birth. \n\nDEBInitNet i...
# Zygodontomys_brevicauda      Missing data on weight at birth, puberty, or u...
#
# [6065 rows x 14 columns]

# %%
df['error_message'].value_counts()
# Out:
# error_message
# Missing data on age at birth. \n\nDEBInitNet initialization method cannot be applied. If the data exists, check that it follows the naming convention. If not, try another initialization method. \n                                                           1695
# Missing data on weight at birth, puberty, or ultimate. \n\nDEBInitNet initialization method cannot be applied. If the data exists, check that it follows the naming convention. If not, try another initialization method. \n                                   925
# The logical indices contain a true value outside of the array bounds.                                                                                                                                                                                           841
# Dimensions of arrays being concatenated are not consistent.                                                                                                                                                                                                     699
# Missing data on reproduction rate. \n\nDEBInitNet initialization method cannot be applied. If the data exists, check that it follows the naming convention. If not, try another initialization method. \n                                                       347
# Not enough input arguments.                                                                                                                                                                                                                                      80
# Maximum execution time exceeded                                                                                                                                                                                                                                  75
# Model type is not compatible. DEBInitNet is only implemented for model types std, stf, stx, and abj.                                                                                                                                                             50
# Parameter 'z' should be set free.                                                                                                                                                                                                                                27
# Incorrect dimensions for matrix multiplication. Check that the number of columns in the first matrix matches the number of rows in the second matrix. To operate on each element of the matrix individually, use TIMES (.*) for elementwise multiplication.       8
# Unrecognized field name "ab".                                                                                                                                                                                                                                     8
# Dot indexing is not supported for variables of this type.                                                                                                                                                                                                         7
# Missing data on lifespan. \n\nDEBInitNet initialization method cannot be applied. If the data exists, check that it follows the naming convention. If not, try another initialization method. \n                                                                  7
# Arrays have incompatible sizes for this operation.                                                                                                                                                                                                                3
# Operands to the logical AND (&&) and OR (||) operators must be convertible to logical scalar values. Use the ANY or ALL functions to reduce operands to logical scalar values.                                                                                    2
# The entries in tspan must strictly increase or decrease.                                                                                                                                                                                                          2
# Index exceeds the number of array elements. Index must not exceed 2.                                                                                                                                                                                              2
# Index exceeds the number of array elements. Index must not exceed 5.                                                                                                                                                                                              1
# Unrecognized function or variable 'predict_Nodipecten_subnodosus'.                                                                                                                                                                                                1
# Index in position 1 is invalid. Array indices must be positive integers or logical values.                                                                                                                                                                        1
# Invalid function name 'pars_init_730+'.                                                                                                                                                                                                                           1
# Index exceeds the number of array elements. Index must not exceed 3.                                                                                                                                                                                              1
# Name: count, dtype: int64

# %%
# Drop rows with no errors
df = df[~df['error_message'].isna()]
# Remove errors from missing data or incompatible model type
# These error messages all contain the string 'DEBInitNet'
df = df[~df['error_message'].str.contains('DEBInitNet')]
# Remove errors from 'z' not being free
df = df[df['error_message'] != "Parameter 'z' should be set free."]
df
# Out:
#                              amp_loss  init_loss  final_loss  execution_time  \
# Row
# Abroscopus_superciliaris          0.0        0.0         0.0        5.010957
# Acanthis_flammea                  0.0        0.0         0.0        7.062847
# Acanthis_hornemanni               0.0        0.0         0.0        6.729335
# Acanthisitta_chloris              0.0        0.0         0.0        9.260610
# Acanthiza_chrysorrhoa             0.0        0.0         0.0        5.026978
# ...                               ...        ...         ...             ...
# Zonotrichia_leucophrys            0.0        0.0         0.0        1.136811
# Zonotrichia_querula               0.0        0.0         0.0        1.273711
# Zosterisessor_ophiocephalus       0.0        0.0         0.0        0.113567
# Zosterops_lateralis               0.0        0.0         0.0        1.159346
# Zosterops_virens                  0.0        0.0         0.0        0.216007
#
#                              predict_failed  estim_error  init_func_error  \
# Row
# Abroscopus_superciliaris              False         True            False
# Acanthis_flammea                      False         True            False
# Acanthis_hornemanni                   False         True            False
# Acanthisitta_chloris                  False         True            False
# Acanthiza_chrysorrhoa                 False         True            False
# ...                                     ...          ...              ...
# Zonotrichia_leucophrys                False         True            False
# Zonotrichia_querula                   False         True            False
# Zosterisessor_ophiocephalus           False        False            False
# Zosterops_lateralis                   False         True            False
# Zosterops_virens                      False        False            False
#
#                              fetch_error  convert_error  debnet_error  \
# Row
# Abroscopus_superciliaris           False          False         False
# Acanthis_flammea                   False          False         False
# Acanthis_hornemanni                False          False         False
# Acanthisitta_chloris               False          False         False
# Acanthiza_chrysorrhoa              False          False         False
# ...                                  ...            ...           ...
# Zonotrichia_leucophrys             False          False         False
# Zonotrichia_querula                False          False         False
# Zosterisessor_ophiocephalus        False          False         False
# Zosterops_lateralis                False          False         False
# Zosterops_virens                   False          False         False
#
#                              predict_error  lossfun_error  error  \
# Row
# Abroscopus_superciliaris             False          False   True
# Acanthis_flammea                     False          False   True
# Acanthis_hornemanni                  False          False   True
# Acanthisitta_chloris                 False          False   True
# Acanthiza_chrysorrhoa                False          False   True
# ...                                    ...            ...    ...
# Zonotrichia_leucophrys               False          False   True
# Zonotrichia_querula                  False          False   True
# Zosterisessor_ophiocephalus          False           True   True
# Zosterops_lateralis                  False          False   True
# Zosterops_virens                     False           True   True
#
#                                                                  error_message
# Row
# Abroscopus_superciliaris     The logical indices contain a true value outsi...
# Acanthis_flammea             The logical indices contain a true value outsi...
# Acanthis_hornemanni          The logical indices contain a true value outsi...
# Acanthisitta_chloris         The logical indices contain a true value outsi...
# Acanthiza_chrysorrhoa        The logical indices contain a true value outsi...
# ...                                                                        ...
# Zonotrichia_leucophrys       The logical indices contain a true value outsi...
# Zonotrichia_querula          The logical indices contain a true value outsi...
# Zosterisessor_ophiocephalus  Dimensions of arrays being concatenated are no...
# Zosterops_lateralis          The logical indices contain a true value outsi...
# Zosterops_virens             Dimensions of arrays being concatenated are no...
#
# [1732 rows x 14 columns]

# %% [markdown]
# # Error exploration

# %%
df[error_columns].sum()
# Out:
# predict_failed        0
# estim_error         851
# init_func_error      91
# fetch_error          90
# convert_error         2
# debnet_error          0
# predict_error        19
# lossfun_error       710
# error              1657
# dtype: int64

# %%
df[error_columns].value_counts()
# Out:
# predict_failed  estim_error  init_func_error  fetch_error  convert_error  debnet_error  predict_error  lossfun_error  error
# False           True         False            False        False          False         False          False          True     836
#                 False        False            False        False          False         False          True           True     710
#                              True             True         False          False         False          False          True      88
#                              False            False        False          False         False          False          False     75
#                 True         False            False        False          False         True           False          True      15
#                 False        False            False        False          False         True           False          True       4
#                              True             True         True           False         False          False          True       2
#                                               False        False          False         False          False          True       1
#                              False            False        False          False         False          False          True       1
# Name: count, dtype: int64

# %%
df['error_message'].value_counts()
# Out:
# error_message
# The logical indices contain a true value outside of the array bounds.                                                                                                                                                                                          841
# Dimensions of arrays being concatenated are not consistent.                                                                                                                                                                                                    699
# Not enough input arguments.                                                                                                                                                                                                                                     80
# Maximum execution time exceeded                                                                                                                                                                                                                                 75
# Unrecognized field name "ab".                                                                                                                                                                                                                                    8
# Incorrect dimensions for matrix multiplication. Check that the number of columns in the first matrix matches the number of rows in the second matrix. To operate on each element of the matrix individually, use TIMES (.*) for elementwise multiplication.      8
# Dot indexing is not supported for variables of this type.                                                                                                                                                                                                        7
# Arrays have incompatible sizes for this operation.                                                                                                                                                                                                               3
# Operands to the logical AND (&&) and OR (||) operators must be convertible to logical scalar values. Use the ANY or ALL functions to reduce operands to logical scalar values.                                                                                   2
# The entries in tspan must strictly increase or decrease.                                                                                                                                                                                                         2
# Index exceeds the number of array elements. Index must not exceed 2.                                                                                                                                                                                             2
# Index exceeds the number of array elements. Index must not exceed 5.                                                                                                                                                                                             1
# Unrecognized function or variable 'predict_Nodipecten_subnodosus'.                                                                                                                                                                                               1
# Index in position 1 is invalid. Array indices must be positive integers or logical values.                                                                                                                                                                       1
# Invalid function name 'pars_init_730+'.                                                                                                                                                                                                                          1
# Index exceeds the number of array elements. Index must not exceed 3.                                                                                                                                                                                             1
# Name: count, dtype: int64

# %%
error_df = df[df['init_func_error']].copy()
error_df['error_message'].value_counts()
# Out:
# error_message
# Not enough input arguments.                                                                                                                                                       80
# Unrecognized field name "ab".                                                                                                                                                      8
# Operands to the logical AND (&&) and OR (||) operators must be convertible to logical scalar values. Use the ANY or ALL functions to reduce operands to logical scalar values.     2
# Invalid function name 'pars_init_730+'.                                                                                                                                            1
# Name: count, dtype: int64

# %%
error_df.sort_values(by='error_message', ascending=False).head(50)
# Out:
#                               amp_loss  init_loss  final_loss  execution_time  \
# Row
# Macrothrix_triserialis             0.0        0.0         0.0        0.467010
# Ilyocryptus_spinifer               0.0        0.0         0.0        0.441211
# Moina_weismanni                    0.0        0.0         0.0        0.350541
# Oxyurella_longicaudis              0.0        0.0         0.0        0.446164
# Leydigia_ciliata                   0.0        0.0         0.0        0.430350
# Nototheniops_larseni               0.0        0.0         0.0        0.335537
# Latonopsis_australis               0.0        0.0         0.0        0.445967
# Neanthes_arenaceodentata           0.0        0.0         0.0        0.442209
# Paleosuchus_trigonatus             0.0        0.0         0.0        0.442928
# Graptemys_ouachitensis             0.0        0.0         0.0        0.333836
# Nacella_concinna                   0.0        0.0         0.0        0.666477
# Physa_fontinalis                   0.0        0.0         0.0        0.333791
# Mytilus_trossulus                  0.0        0.0         0.0        0.442450
# Mysis_mixta                        0.0        0.0         0.0        0.442218
# Oikopleura_dioica                  0.0        0.0         0.0        0.444746
# Ophiomusa_lymani                   0.0        0.0         0.0        0.332211
# Ophiura_albida                     0.0        0.0         0.0        0.341017
# Ophiura_ophiura                    0.0        0.0         0.0        0.769280
# Mya_arenaria                       0.0        0.0         0.0        0.338548
# Moina_micrura                      0.0        0.0         0.0        0.349999
# Pecten_maximus                     0.0        0.0         0.0        0.555109
# Perna_canaliculus                  0.0        0.0         0.0        0.997939
# Perna_viridis                      0.0        0.0         0.0        0.554574
# Aegopinella_epipedostoma           0.0        0.0         0.0        1.107782
# Mercenaria_mercenaria              0.0        0.0         0.0        0.445491
# Spisula_solidissima                0.0        0.0         0.0        0.611715
# Tiliqua_rugosa                     0.0        0.0         0.0        0.459046
# Teredo_navalis                     0.0        0.0         0.0        0.951007
# Tanymastix_stagnalis               0.0        0.0         0.0        0.443753
# Streptocephalus_torvicornis        0.0        0.0         0.0        0.570105
# Streptocephalus_sirindhornae       0.0        0.0         0.0        0.570418
# Streptocephalus_siamensis          0.0        0.0         0.0        0.554530
# Streptocephalus_sealii             0.0        0.0         0.0        0.559194
# Sterechinus_neumayeri              0.0        0.0         0.0        0.940575
# Spisula_subtruncata                0.0        0.0         0.0        0.590181
# Solea_solea                        0.0        0.0         0.0        1.535024
# Placopecten_magellanicus           0.0        0.0         0.0        0.997054
# Solea_senegalensis                 0.0        0.0         0.0        1.762190
# Ruditapes_philippinarum            0.0        0.0         0.0        0.575730
# Pseudosida_bidentata               0.0        0.0         0.0        0.441773
# Pseudophryne_bibronii              0.0        0.0         0.0        0.667761
# Praunus_flexuosus                  0.0        0.0         0.0        0.333610
# Pleuroxus_striatus                 0.0        0.0         0.0        0.334373
# Pleuroxus_aduncus                  0.0        0.0         0.0        0.333863
# Pleurobrachia_pileus               0.0        0.0         0.0        0.444969
# Pleurobrachia_bachei               0.0        0.0         0.0        0.539092
# Physella_gyrina                    0.0        0.0         0.0        0.334730
# Macrothrix_flabelligera            0.0        0.0         0.0        0.449445
# Meganyctiphanes_norvegica          0.0        0.0         0.0        0.665104
# Corbula_gibba                      0.0        0.0         0.0        0.445398
#
#                               predict_failed  estim_error  init_func_error  \
# Row
# Macrothrix_triserialis                 False        False             True
# Ilyocryptus_spinifer                   False        False             True
# Moina_weismanni                        False        False             True
# Oxyurella_longicaudis                  False        False             True
# Leydigia_ciliata                       False        False             True
# Nototheniops_larseni                   False        False             True
# Latonopsis_australis                   False        False             True
# Neanthes_arenaceodentata               False        False             True
# Paleosuchus_trigonatus                 False        False             True
# Graptemys_ouachitensis                 False        False             True
# Nacella_concinna                       False        False             True
# Physa_fontinalis                       False        False             True
# Mytilus_trossulus                      False        False             True
# Mysis_mixta                            False        False             True
# Oikopleura_dioica                      False        False             True
# Ophiomusa_lymani                       False        False             True
# Ophiura_albida                         False        False             True
# Ophiura_ophiura                        False        False             True
# Mya_arenaria                           False        False             True
# Moina_micrura                          False        False             True
# Pecten_maximus                         False        False             True
# Perna_canaliculus                      False        False             True
# Perna_viridis                          False        False             True
# Aegopinella_epipedostoma               False        False             True
# Mercenaria_mercenaria                  False        False             True
# Spisula_solidissima                    False        False             True
# Tiliqua_rugosa                         False        False             True
# Teredo_navalis                         False        False             True
# Tanymastix_stagnalis                   False        False             True
# Streptocephalus_torvicornis            False        False             True
# Streptocephalus_sirindhornae           False        False             True
# Streptocephalus_siamensis              False        False             True
# Streptocephalus_sealii                 False        False             True
# Sterechinus_neumayeri                  False        False             True
# Spisula_subtruncata                    False        False             True
# Solea_solea                            False        False             True
# Placopecten_magellanicus               False        False             True
# Solea_senegalensis                     False        False             True
# Ruditapes_philippinarum                False        False             True
# Pseudosida_bidentata                   False        False             True
# Pseudophryne_bibronii                  False        False             True
# Praunus_flexuosus                      False        False             True
# Pleuroxus_striatus                     False        False             True
# Pleuroxus_aduncus                      False        False             True
# Pleurobrachia_pileus                   False        False             True
# Pleurobrachia_bachei                   False        False             True
# Physella_gyrina                        False        False             True
# Macrothrix_flabelligera                False        False             True
# Meganyctiphanes_norvegica              False        False             True
# Corbula_gibba                          False        False             True
#
#                               fetch_error  convert_error  debnet_error  \
# Row
# Macrothrix_triserialis               True          False         False
# Ilyocryptus_spinifer                 True          False         False
# Moina_weismanni                      True          False         False
# Oxyurella_longicaudis                True          False         False
# Leydigia_ciliata                     True          False         False
# Nototheniops_larseni                 True          False         False
# Latonopsis_australis                 True          False         False
# Neanthes_arenaceodentata             True          False         False
# Paleosuchus_trigonatus               True           True         False
# Graptemys_ouachitensis               True           True         False
# Nacella_concinna                     True          False         False
# Physa_fontinalis                     True          False         False
# Mytilus_trossulus                    True          False         False
# Mysis_mixta                          True          False         False
# Oikopleura_dioica                    True          False         False
# Ophiomusa_lymani                     True          False         False
# Ophiura_albida                       True          False         False
# Ophiura_ophiura                      True          False         False
# Mya_arenaria                         True          False         False
# Moina_micrura                        True          False         False
# Pecten_maximus                       True          False         False
# Perna_canaliculus                    True          False         False
# Perna_viridis                        True          False         False
# Aegopinella_epipedostoma             True          False         False
# Mercenaria_mercenaria                True          False         False
# Spisula_solidissima                  True          False         False
# Tiliqua_rugosa                       True          False         False
# Teredo_navalis                       True          False         False
# Tanymastix_stagnalis                 True          False         False
# Streptocephalus_torvicornis          True          False         False
# Streptocephalus_sirindhornae         True          False         False
# Streptocephalus_siamensis            True          False         False
# Streptocephalus_sealii               True          False         False
# Sterechinus_neumayeri                True          False         False
# Spisula_subtruncata                  True          False         False
# Solea_solea                          True          False         False
# Placopecten_magellanicus             True          False         False
# Solea_senegalensis                   True          False         False
# Ruditapes_philippinarum              True          False         False
# Pseudosida_bidentata                 True          False         False
# Pseudophryne_bibronii                True          False         False
# Praunus_flexuosus                    True          False         False
# Pleuroxus_striatus                   True          False         False
# Pleuroxus_aduncus                    True          False         False
# Pleurobrachia_pileus                 True          False         False
# Pleurobrachia_bachei                 True          False         False
# Physella_gyrina                      True          False         False
# Macrothrix_flabelligera              True          False         False
# Meganyctiphanes_norvegica            True          False         False
# Corbula_gibba                        True          False         False
#
#                               predict_error  lossfun_error  error  \
# Row
# Macrothrix_triserialis                False          False   True
# Ilyocryptus_spinifer                  False          False   True
# Moina_weismanni                       False          False   True
# Oxyurella_longicaudis                 False          False   True
# Leydigia_ciliata                      False          False   True
# Nototheniops_larseni                  False          False   True
# Latonopsis_australis                  False          False   True
# Neanthes_arenaceodentata              False          False   True
# Paleosuchus_trigonatus                False          False   True
# Graptemys_ouachitensis                False          False   True
# Nacella_concinna                      False          False   True
# Physa_fontinalis                      False          False   True
# Mytilus_trossulus                     False          False   True
# Mysis_mixta                           False          False   True
# Oikopleura_dioica                     False          False   True
# Ophiomusa_lymani                      False          False   True
# Ophiura_albida                        False          False   True
# Ophiura_ophiura                       False          False   True
# Mya_arenaria                          False          False   True
# Moina_micrura                         False          False   True
# Pecten_maximus                        False          False   True
# Perna_canaliculus                     False          False   True
# Perna_viridis                         False          False   True
# Aegopinella_epipedostoma              False          False   True
# Mercenaria_mercenaria                 False          False   True
# Spisula_solidissima                   False          False   True
# Tiliqua_rugosa                        False          False   True
# Teredo_navalis                        False          False   True
# Tanymastix_stagnalis                  False          False   True
# Streptocephalus_torvicornis           False          False   True
# Streptocephalus_sirindhornae          False          False   True
# Streptocephalus_siamensis             False          False   True
# Streptocephalus_sealii                False          False   True
# Sterechinus_neumayeri                 False          False   True
# Spisula_subtruncata                   False          False   True
# Solea_solea                           False          False   True
# Placopecten_magellanicus              False          False   True
# Solea_senegalensis                    False          False   True
# Ruditapes_philippinarum               False          False   True
# Pseudosida_bidentata                  False          False   True
# Pseudophryne_bibronii                 False          False   True
# Praunus_flexuosus                     False          False   True
# Pleuroxus_striatus                    False          False   True
# Pleuroxus_aduncus                     False          False   True
# Pleurobrachia_pileus                  False          False   True
# Pleurobrachia_bachei                  False          False   True
# Physella_gyrina                       False          False   True
# Macrothrix_flabelligera               False          False   True
# Meganyctiphanes_norvegica             False          False   True
# Corbula_gibba                         False          False   True
#
#                                                                   error_message
# Row
# Macrothrix_triserialis                            Unrecognized field name "ab".
# Ilyocryptus_spinifer                              Unrecognized field name "ab".
# Moina_weismanni                                   Unrecognized field name "ab".
# Oxyurella_longicaudis                             Unrecognized field name "ab".
# Leydigia_ciliata                                  Unrecognized field name "ab".
# Nototheniops_larseni                              Unrecognized field name "ab".
# Latonopsis_australis                              Unrecognized field name "ab".
# Neanthes_arenaceodentata                          Unrecognized field name "ab".
# Paleosuchus_trigonatus        Operands to the logical AND (&&) and OR (||) o...
# Graptemys_ouachitensis        Operands to the logical AND (&&) and OR (||) o...
# Nacella_concinna                                    Not enough input arguments.
# Physa_fontinalis                                    Not enough input arguments.
# Mytilus_trossulus                                   Not enough input arguments.
# Mysis_mixta                                         Not enough input arguments.
# Oikopleura_dioica                                   Not enough input arguments.
# Ophiomusa_lymani                                    Not enough input arguments.
# Ophiura_albida                                      Not enough input arguments.
# Ophiura_ophiura                                     Not enough input arguments.
# Mya_arenaria                                        Not enough input arguments.
# Moina_micrura                                       Not enough input arguments.
# Pecten_maximus                                      Not enough input arguments.
# Perna_canaliculus                                   Not enough input arguments.
# Perna_viridis                                       Not enough input arguments.
# Aegopinella_epipedostoma                            Not enough input arguments.
# Mercenaria_mercenaria                               Not enough input arguments.
# Spisula_solidissima                                 Not enough input arguments.
# Tiliqua_rugosa                                      Not enough input arguments.
# Teredo_navalis                                      Not enough input arguments.
# Tanymastix_stagnalis                                Not enough input arguments.
# Streptocephalus_torvicornis                         Not enough input arguments.
# Streptocephalus_sirindhornae                        Not enough input arguments.
# Streptocephalus_siamensis                           Not enough input arguments.
# Streptocephalus_sealii                              Not enough input arguments.
# Sterechinus_neumayeri                               Not enough input arguments.
# Spisula_subtruncata                                 Not enough input arguments.
# Solea_solea                                         Not enough input arguments.
# Placopecten_magellanicus                            Not enough input arguments.
# Solea_senegalensis                                  Not enough input arguments.
# Ruditapes_philippinarum                             Not enough input arguments.
# Pseudosida_bidentata                                Not enough input arguments.
# Pseudophryne_bibronii                               Not enough input arguments.
# Praunus_flexuosus                                   Not enough input arguments.
# Pleuroxus_striatus                                  Not enough input arguments.
# Pleuroxus_aduncus                                   Not enough input arguments.
# Pleurobrachia_pileus                                Not enough input arguments.
# Pleurobrachia_bachei                                Not enough input arguments.
# Physella_gyrina                                     Not enough input arguments.
# Macrothrix_flabelligera                             Not enough input arguments.
# Meganyctiphanes_norvegica                           Not enough input arguments.
# Corbula_gibba                                       Not enough input arguments.

# %%
error_df[error_columns].value_counts()
# Out:
# predict_failed  estim_error  init_func_error  fetch_error  convert_error  debnet_error  predict_error  lossfun_error  error
# False           False        True             True         False          False         False          False          True     88
#                                                            True           False         False          False          True      2
#                                               False        False          False         False          False          True      1
# Name: count, dtype: int64
